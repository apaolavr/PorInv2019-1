# %% [markdown]
# # Selección de portafolios usando simulación Montecarlo

# %% [markdown]
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/6e/Separation_theorem_of_MPT.svg/2000px-Separation_theorem_of_MPT.svg.png" width="400px" height="400px" />
#
# > Durante el curso, específicamente en los módulos dos y tres, elaboramos toda la fundamentación de la teoría moderna de portafolios de Markowitz. Ésta se basa en la existencia de una línea especial en el espacio de rendimiento esperado vs. volatilidad, llamada **frontera de mínima varianza**.
#
# > Al finalizar el módulo 3, vimos que no importa la cantidad de activos riesgosos que se tengan, si encontramos dos portafolios sobre la frontera eficiente, podemos reconstruirla. Dos portafolios importantes que hallamos en el curso fueron:
#
# > - **Portafolio de mínima varianza**: ¿cómo se obtiene?
# > - **Portafolio eficiente en media varianza**: ¿cómo se obtiene?
#
# > Por otra parte, resolver problemas de optimización cuando la cantidad de variables crece, se vuelve un problema complejo, computacionalmente hablando. Así que desarrollar métodos alternativos a la optimización que nos permitan encontrar los anteriores portafolios es de gran interés...

# %% [markdown]
# ## 1. Descargamos activos de la BMV
#
# Por simplicidad, y para entender las ideas alrededor de la selección de portafolios usando simulación montecarlo, utilizaremos únicamente tres activos de la BMV: Cemex, Grupo Carso y Grupo Financiero Banorte.

# %% [markdown]
# 1.1. Descargar precios mensuales ajustados en el cierre para los tres activos mencionados anteriormente en los últimos 5 años:

# %%
# Importar librerías

# %%
# Función para descargar precios de cierre ajustados:
def get_adj_closes(tickers, start_date=None, end_date=None, freq='m'):
    # Fecha inicio por defecto (start_date='2010-01-01') y fecha fin por defecto (end_date=today)
    # Descargamos DataFrame con todos los datos
    closes = web.YahooDailyReader(symbols=tickers, start=start_date, end=end_date, interval=freq).read()['Adj Close']
    # Se ordenan los índices de manera ascendente
    closes.sort_index(inplace=True)
    return closes

# %%
# Descargar precios y graficar

# %% [markdown]
# 1.2. A partir de los precios, obtener los rendimientos mensuales:

# %%
# Obtener rendimientos mensuales y graficar

# %% [markdown]
# 1.3. Finalmente, a partir de los rendimientos mensuales, estimar la tendencia central de los rendimientos (rendimiento esperado), y caracterizar el riesgo de los activos (varianzas y covarianzas)

# %%
# Resumen: rendimiento medio mensual y volatilidad
# Out:
#                    RE       Vol
# Symbols
# CEMEXCPO.MX -0.003106  0.094496
# GCARSOA1.MX  0.002798  0.059991
# GFNORTEO.MX  0.008466  0.062968

# %%
# Matriz de covarianza
# Out:
# Symbols      CEMEXCPO.MX  GCARSOA1.MX  GFNORTEO.MX
# Symbols
# CEMEXCPO.MX     0.008930     0.001763     0.000955
# GCARSOA1.MX     0.001763     0.003599     0.000868
# GFNORTEO.MX     0.000955     0.000868     0.003965

# %%
# Matriz de correlación
# Out:
# Symbols      CEMEXCPO.MX  GCARSOA1.MX  GFNORTEO.MX
# Symbols
# CEMEXCPO.MX     1.000000     0.310953     0.160441
# GCARSOA1.MX     0.310953     1.000000     0.229744
# GFNORTEO.MX     0.160441     0.229744     1.000000

# %% [markdown]
# ___
# ## 2. Selección de portafolios mediante montecarlo
#
# Antes de continuar, consultamos la tasa libre de riesgo al día de hoy en [Banxico](http://www.banxico.org.mx/):

# %%
# Tasa libre de riesgo

# %% [markdown]
# ¿Alguien tiene alguna idea de lo que es simulación montecarlo?
#
# En cuanto a la selección de portafolios, lo que hacemos es simular una gran cantidad de posibles portafolios que se pueden construir con los activos dados (generamos muchas ponderaciones posibles), y calculamos su rendimiento esperado y volatilidad para dibujarlos, y así poder identificar objetos de interés:
#
# - frontera eficiente;
# - portafolio de mínima varianza;
# - portafolio EMV...

# %%
# Definimos el número de portafolios que simularemos, y la cantidad de activos que tenemos

# %% [markdown]
# 2.1. Generamos los portafolios

# %%
# Generar una matriz de pesos de n_port x n_act, tal que cada fila sume uno (recordar restricción)

# %%
# Rendimientos y volatilidad de cada portafolios

# %%
# Radio de Sharpe

# %%
# Data frame de resultados
# Out:
#             RE       Vol        SR     Cemex    GCarso   Banorte
# 0     0.001238  0.055782 -0.100310  0.385503  0.488226  0.126272
# 1     0.003541  0.050443 -0.065264  0.300315  0.255771  0.443914
# 2     0.003727  0.057248 -0.054257  0.402333  0.014670  0.582997
# 3     0.002384  0.055379 -0.080334  0.428510  0.198116  0.373373
# 4     0.005774  0.048238 -0.021951  0.032731  0.408056  0.559214
# 5     0.002611  0.050345 -0.083871  0.229148  0.565199  0.205653
# 6     0.002459  0.057577 -0.075982  0.463227  0.114177  0.422595
# 7     0.003834  0.047571 -0.063041  0.152090  0.506654  0.341256
# 8     0.001356  0.056409 -0.097108  0.434873  0.366665  0.198463
# 9     0.003017  0.051600 -0.073954  0.111337  0.734027  0.154636
# 10    0.000392  0.069187 -0.093105  0.665886  0.065075  0.269039
# 11    0.003358  0.050861 -0.068337  0.315870  0.256388  0.427743
# 12    0.000458  0.070870 -0.089953  0.688591  0.006955  0.304454
# 13    0.001438  0.057074 -0.094529  0.458388  0.304076  0.237536
# 14    0.006992  0.052818  0.003010  0.014989  0.229411  0.755599
# 15    0.004370  0.051654 -0.047693  0.279991  0.151062  0.568946
# 16    0.003396  0.057943 -0.059326  0.429522  0.017626  0.552852
# 17    0.000034  0.067235 -0.101128  0.631192  0.199027  0.169782
# 18    0.003737  0.053444 -0.057928  0.347578  0.124655  0.527767
# 19    0.000847  0.057557 -0.104013  0.379796  0.568898  0.051306
# 20    0.002944  0.050728 -0.076673  0.318693  0.323630  0.357676
# 21    0.002284  0.057287 -0.079409  0.463158  0.145075  0.391767
# 22    0.001160  0.056193 -0.100965  0.328365  0.618651  0.052984
# 23    0.002077  0.052067 -0.091355  0.305051  0.504467  0.190482
# 24    0.001446  0.054674 -0.098545  0.336798  0.551022  0.112180
# 25    0.001799  0.053435 -0.094223  0.354869  0.451844  0.193287
# 26    0.000339  0.062139 -0.104512  0.530724  0.350312  0.118964
# 27    0.004055  0.047314 -0.058718  0.140670  0.491020  0.368310
# 28    0.003491  0.048354 -0.069122  0.230558  0.407040  0.362402
# 29    0.004558  0.049494 -0.045968  0.003477  0.682373  0.314150
# ...        ...       ...       ...       ...       ...       ...
# 9970  0.002664  0.050723 -0.082189  0.311347  0.387930  0.300722
# 9971 -0.001024  0.073459 -0.106966  0.712645  0.219430  0.067925
# 9972  0.005098  0.049049 -0.035375  0.168230  0.250727  0.581043
# 9973  0.002529  0.050566 -0.085127  0.238927  0.559717  0.201356
# 9974  0.004536  0.047065 -0.048816  0.118653  0.451173  0.430174
# 9975 -0.000422  0.066900 -0.108455  0.599874  0.343458  0.056668
# 9976  0.002695  0.051073 -0.081030  0.173156  0.664695  0.162148
# 9977  0.003163  0.051775 -0.070888  0.341541  0.238308  0.420151
# 9978  0.002533  0.057127 -0.075276  0.454184  0.119491  0.426325
# 9979  0.002160  0.053940 -0.086646  0.178980  0.747241  0.073779
# 9980  0.002947  0.051393 -0.075622  0.336916  0.285900  0.377185
# 9981  0.000857  0.058538 -0.102086  0.462693  0.397756  0.139552
# 9982  0.003913  0.047579 -0.061376  0.187322  0.420842  0.391835
# 9983  0.003596  0.047873 -0.067632  0.187230  0.477049  0.335721
# 9984 -0.000176  0.064848 -0.108083  0.563413  0.374387  0.062200
# 9985  0.002228  0.053653 -0.085844  0.392185  0.299961  0.307855
# 9986  0.001875  0.058032 -0.085448  0.482097  0.178669  0.339235
# 9987  0.003006  0.050247 -0.076163  0.303800  0.343008  0.353192
# 9988  0.003316  0.053862 -0.065307  0.374525  0.144023  0.481452
# 9989  0.002664  0.052018 -0.080160  0.149949  0.717596  0.132455
# 9990  0.002541  0.056392 -0.076114  0.079328  0.883392  0.037281
# 9991  0.000899  0.061659 -0.096244  0.544672  0.223051  0.232277
# 9992  0.005742  0.051415 -0.021219  0.156746  0.160535  0.682719
# 9993  0.002959  0.058032 -0.066754  0.451501  0.049741  0.498758
# 9994  0.003833  0.049311 -0.060838  0.261049  0.284389  0.454562
# 9995  0.003142  0.050026 -0.073785  0.136817  0.659979  0.203205
# 9996  0.000027  0.062132 -0.109548  0.471014  0.527303  0.001683
# 9997  0.002258  0.056099 -0.081558  0.443480  0.189879  0.366641
# 9998  0.004122  0.047255 -0.057380  0.154449  0.451135  0.394416
# 9999  0.006150  0.053224 -0.012841  0.146027  0.110512  0.743461
#
# [10000 rows x 6 columns]

# %% [markdown]
# 2.2. Aproximar portafolio de mínima varianza y portafolio eficiente en media varianza

# %%
# Portafolio EMV
# Out:
# RE         0.008383
# Vol        0.062347
# SR         0.024863
# Cemex      0.001729
# GCarso     0.011040
# Banorte    0.987230
# Name: 2277, dtype: float64

# %%
# Portafolio mínima varianza
# Out:
# RE         0.004611
# Vol        0.047061
# SR        -0.047219
# Cemex      0.111142
# GCarso     0.453216
# Banorte    0.435642
# Name: 5979, dtype: float64

# %% [markdown]
# 2.3. Dibujar todos los portafolios en el espacio de rendimiento esperado vs. volatilidad

# %%
# Gráfica

# EMV

# Min var

# %% [markdown]
# ## 3. Comparar con los resultados obtenidos por optimización

# %% [markdown]
# 3.1. Portafolio de mínima varianza

# %%
# Importamos funcion minimize del modulo optimize de scipy

# %%
## Construcción de parámetros
# 1. Sigma: matriz de varianza-covarianza

# 2. Eind: rendimientos esperados activos individuales

# %%
# Función objetivo

# %%
# Dato inicial

# Cotas de las variables

# Restricciones

# %%
# Portafolio de mínima varianza
# Out:
#      fun: 0.0022181886407200537
#      jac: array([0.00444718, 0.00429039, 0.00457167])
#  message: 'Optimization terminated successfully.'
#     nfev: 25
#      nit: 5
#     njev: 5
#   status: 0
#  success: True
#        x: array([0.11555805, 0.42984713, 0.45459482])

# %%
# Comparar
# Out:
# RE         0.004611
# Vol        0.047061
# SR        -0.047219
# Cemex      0.111142
# GCarso     0.453216
# Banorte    0.435642
# Name: 5979, dtype: float64

# %% [markdown]
# 3.2. Portafolio EMV

# %%
# Función objetivo

# %%
# Dato inicial

# Cotas de las variables

# Restricciones

# %%
# Portafolio EMV
# Out:
#      fun: -0.025929542397658562
#      jac: array([ 0.05556626, -0.03876167, -0.10852022])
#  message: 'Optimization terminated successfully.'
#     nfev: 25
#      nit: 5
#     njev: 5
#   status: 0
#  success: True
#        x: array([0.00000000e+00, 1.38777878e-16, 1.00000000e+00])

# %%
# Comparar
# Out:
# RE         0.008383
# Vol        0.062347
# SR         0.024863
# Cemex      0.001729
# GCarso     0.011040
# Banorte    0.987230
# Name: 2277, dtype: float64

# %% [markdown]
# # Conclusión
#
# - Tenemos una herramienta para aproximar toda la teoría de Markowitz.
#
# - Esta herramienta no involucra optimización, solo generar números aleatorios normalizados.
#
# - Por tanto, no le afecta el problema de dimensión (cuando tenemos muchos activos).

# %% [markdown]
# ## Esto lo usarán en la actividad en conjunto con las demás herramientas vistas en el módulo 3 (LAC, distribución óptima de capital).

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
